# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
# dataset

n= 1000

data = np.random.randn(n)**2

# %%
plt.plot(data,'o')

# %%
plt.hist(data,bins=30)
# Out:
# (array([457., 146.,  92.,  77.,  49.,  44.,  28.,  26.,  18.,   9.,  11.,
#          10.,   5.,   5.,   4.,   2.,   4.,   2.,   2.,   2.,   1.,   1.,
#           1.,   0.,   1.,   0.,   0.,   1.,   1.,   1.]),
#  array([4.71286441e-05, 3.60649858e-01, 7.21252587e-01, 1.08185532e+00,
#         1.44245805e+00, 1.80306078e+00, 2.16366350e+00, 2.52426623e+00,
#         2.88486896e+00, 3.24547169e+00, 3.60607442e+00, 3.96667715e+00,
#         4.32727988e+00, 4.68788261e+00, 5.04848534e+00, 5.40908807e+00,
#         5.76969080e+00, 6.13029353e+00, 6.49089626e+00, 6.85149899e+00,
#         7.21210172e+00, 7.57270444e+00, 7.93330717e+00, 8.29390990e+00,
#         8.65451263e+00, 9.01511536e+00, 9.37571809e+00, 9.73632082e+00,
#         1.00969236e+01, 1.04575263e+01, 1.08181290e+01]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## IQR

# %%
stats.iqr(data)
# Out:
# 1.2707699772426218
