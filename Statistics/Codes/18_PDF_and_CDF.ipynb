# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
# Making Log normal Distribution

x = np.linspace(0,5,1001)
x
# Out:
# array([0.   , 0.005, 0.01 , ..., 4.99 , 4.995, 5.   ])

# %%
p1 = stats.lognorm.pdf(x,1)
c1 = stats.lognorm.cdf(x,1)

# %%
p1,c1
# Out:
# (array([0.00000000e+00, 6.39950626e-05, 9.90238665e-04, ...,
#         2.19651199e-02, 2.19078250e-02, 2.18507148e-02]),
#  array([0.        , 0.00403462, 0.0106511 , ..., 0.78922006, 0.78936466,
#         0.78950906]))

# %%
p2 = stats.lognorm.pdf(x,.1)
c2 = stats.lognorm.cdf(x,.1)

# %%
p2,c2
# Out:
# (array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         6.24044036e-57, 5.30693267e-57, 4.51334809e-57]),
#  array([0., 0., 0., ..., 1., 1., 1.]))

# %%
fig, ax = plt.subplots(2,1,figsize=(8,6))

ax[0].plot(x,p1/sum(p1))
ax[0].plot(x,p1/sum(p1),x,p2/sum(p2))
ax[0].set_ylabel('Probability')
ax[0].set_title('PDF(x)')

ax[1].plot(x,c1)
ax[1].plot(x,c1,x,c2)
ax[1].set_ylabel('Probability')
ax[1].set_title('CDF(x)')
# Out:
# Text(0.5, 1.0, 'CDF(x)')
