# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DATA DESCRIPTION
# ```
# file name -> Columns
# quater-i.csv -> ['order_id', 'quantity', 'item_id', 'choice_description_id' 'item_price']
# items.csv -> ['item_id', 'item_name']
# ```
# Dataset Link - https://drive.google.com/drive/folders/1Z0kaFybvgFeczeUj4dldUnhTdloLqLsL?usp=share_link

# %%
# import like this
items_path = "/content/items.csv"
q1_path = "/content/quarter-1.csv"
q2_path = "/content/quarter-2.csv"
q3_path = "/content/quarter-3.csv"


q1= pd.read_csv(q1_path)
q2 = pd.read_csv(q2_path)
q3 = pd.read_csv(q3_path)

items = pd.read_csv(items_path)

# %% [markdown]
# ###`Q:1-5`
# 1. You are given three quater files, your job is to append these three files and make a single dataframe.
# 2. Have a index as Q-1 Q-2 Q-3 for respective quater files in the dataframe
# 3. Your are given a file items.csv which has item_id and item_name. Find out most sold items in each quarter.
# 4. Find out items which has made most revenue in each quarter.
# 5. Find out avg order price of each quarter.
#
# ***Note: item_price is given as str with $ sign, in earlier task you have converted this to rupees, here too first convert item_price field in rupees.***

# %%
# code here
#1,2)
each_quarter_data = pd.concat([q1,q2,q3],keys=['Q1','Q2','Q3']).reset_index()
each_quarter_data
# Out:
#      level_0  level_1  order_id  quantity  item_id  choice_description_id  \
# 0         Q1        0         1         1        1                      1
# 1         Q1        1         1         1        2                      2
# 2         Q1        2         2         2        4                      3
# 3         Q1        3         4         1        7                      6
# 4         Q1        4         6         1        9                      8
# ...      ...      ...       ...       ...      ...                    ...
# 4620      Q2     2345      1832         1        8                      0
# 4621      Q2     2346      1834         1       20                    515
# 4622      Q3        0        10         1        4                     14
# 4623      Q3        1        11         1       13                     15
# 4624      Q3        2        12         1       11                     17
#
#      item_price
# 0        $3.39
# 1        $3.39
# 2       $16.98
# 3        $9.25
# 4        $8.75
# ...         ...
# 4620     $4.45
# 4621    $11.25
# 4622     $8.75
# 4623     $8.99
# 4624    $10.98
#
# [4625 rows x 7 columns]

# %%
# 3)

grouped_data = items.merge(each_quarter_data, how='inner', on='item_id').groupby('level_0')['item_name'].value_counts()
print(grouped_data)
# Get the indices of the highest values for each group
highest_indices = grouped_data.groupby('level_0').idxmax()
print(highest_indices)
# Get the highest values based on the indices
highest_values = grouped_data.loc[highest_indices]
print(type(highest_values))
highest_values
# Out:
# level_0  item_name
# Q1       Chicken Bowl           351
#          Chicken Burrito        269
#          Chips and Guacamole    245
#          Steak Burrito          184
#          Canned Soft Drink      126
#                                ...
# Q2       Bowl                     1
#          Veggie Crispy Tacos      1
# Q3       Barbacoa Burrito         1
#          Chicken Bowl             1
#          Chicken Burrito          1
# Name: item_name, Length: 98, dtype: int64
# level_0
# Q1        (Q1, Chicken Bowl)
# Q2        (Q2, Chicken Bowl)
# Q3    (Q3, Barbacoa Burrito)
# Name: item_name, dtype: object
# <class 'pandas.core.series.Series'>
# level_0  item_name
# Q1       Chicken Bowl        351
# Q2       Chicken Bowl        375
# Q3       Barbacoa Burrito      1
# Name: item_name, dtype: int64

# %%
each_quarter_data['item_price'] = each_quarter_data['item_price'].astype(float)
each_quarter_data
# Out:
#      level_0  level_1  order_id  quantity  item_id  choice_description_id  \
# 0         Q1        0         1         1        1                      1
# 1         Q1        1         1         1        2                      2
# 2         Q1        2         2         2        4                      3
# 3         Q1        3         4         1        7                      6
# 4         Q1        4         6         1        9                      8
# ...      ...      ...       ...       ...      ...                    ...
# 4620      Q2     2345      1832         1        8                      0
# 4621      Q2     2346      1834         1       20                    515
# 4622      Q3        0        10         1        4                     14
# 4623      Q3        1        11         1       13                     15
# 4624      Q3        2        12         1       11                     17
#
#       item_price
# 0           3.39
# 1           3.39
# 2          16.98
# 3           9.25
# 4           8.75
# ...          ...
# 4620        4.45
# 4621       11.25
# 4622        8.75
# 4623        8.99
# 4624       10.98
#
# [4625 rows x 7 columns]

# %% [markdown]
# grouped_data.groupby('level_0').idxmax() returns the indices of the highest values for each group based on the 'level_0' column. Then, grouped_data.loc[highest_indices] retrieves the corresponding highest values from the grouped data using the indices. Finally, you can print or further process the highest_values as needed.

# %%
# 4)
item_groups = items.merge(each_quarter_data, how='inner', on='item_id').groupby(['level_0','item_name'])['item_price'].sum()
highest_indices = item_groups.groupby('level_0').idxmax()
#print(highest_indices)
items_with_highest_revenues = item_groups.loc[highest_indices]
items_with_highest_revenues
# Out:
# level_0  item_name
# Q1       Chicken Bowl       3525.72
# Q2       Chicken Bowl       3817.01
# Q3       Chicken Burrito      10.98
# Name: item_price, dtype: float64

# %%
# 5)

items.merge(each_quarter_data, how='inner', on='item_id').groupby(['level_0'])['item_price'].mean()
# Out:
# level_0
# Q1    7.577138
# Q2    7.354994
# Q3    9.573333
# Name: item_price, dtype: float64

# %% [markdown]
# ###`Q-6` From the IPL dataset you have to find the Purple cap holder each season.
#
# *Note: Bowler with most no wickets in a season gets purple cap. If more than one bowler have same no of wickets in the season, one with least ecomnomy among them is purple cap holder.*
#
# Bowler's Economy = runs-conceded per six balls

# %%
# code here
ipl = pd.read_csv('/content/IPL_Matches_2008_2022.csv')

ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney  Nitin Menon

# %%
# ball by ball deliveries
bbb_deliveries = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')

bbb_deliveries.head(2)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
# bowler economy rate
ipl_info = ipl.merge(bbb_deliveries, on='ID')
ipl_info['EconomyRate'] = ipl_info.groupby(['Season', 'bowler'])['total_run'].transform(lambda x: x.sum() / (len(x) // 6))
ipl_info[ipl_info['bowler'] == 'Mohammed Shami']
# Out:
# <ipython-input-97-66f7e5b3dc64>:3: RuntimeWarning: divide by zero encountered in long_scalars
#   ipl_info['EconomyRate'] = ipl_info.groupby(['Season', 'bowler'])['total_run'].transform(lambda x: x.sum() / (len(x) // 6))
# <ipython-input-97-66f7e5b3dc64>:3: RuntimeWarning: invalid value encountered in long_scalars
#   ipl_info['EconomyRate'] = ipl_info.groupby(['Season', 'bowler'])['total_run'].transform(lambda x: x.sum() / (len(x) // 6))
#              ID       City        Date Season MatchNumber             Team1  \
# 0       1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 1       1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 2       1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 3       1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 4       1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# ...         ...        ...         ...    ...         ...               ...
# 147743   598005     Jaipur  2013-04-08   2013           8  Rajasthan Royals
# 147744   598005     Jaipur  2013-04-08   2013           8  Rajasthan Royals
# 147745   598005     Jaipur  2013-04-08   2013           8  Rajasthan Royals
# 147746   598005     Jaipur  2013-04-08   2013           8  Rajasthan Royals
# 147747   598005     Jaipur  2013-04-08   2013           8  Rajasthan Royals
#
#                         Team2                             Venue  \
# 0              Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 1              Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 2              Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 3              Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 4              Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# ...                       ...                               ...
# 147743  Kolkata Knight Riders            Sawai Mansingh Stadium
# 147744  Kolkata Knight Riders            Sawai Mansingh Stadium
# 147745  Kolkata Knight Riders            Sawai Mansingh Stadium
# 147746  Kolkata Knight Riders            Sawai Mansingh Stadium
# 147747  Kolkata Knight Riders            Sawai Mansingh Stadium
#
#                    TossWinner TossDecision  ... batsman_run extras_run  \
# 0            Rajasthan Royals          bat  ...           0          0
# 1            Rajasthan Royals          bat  ...           0          1
# 2            Rajasthan Royals          bat  ...           1          0
# 3            Rajasthan Royals          bat  ...           0          0
# 4            Rajasthan Royals          bat  ...           0          0
# ...                       ...          ...  ...         ...        ...
# 147743  Kolkata Knight Riders        field  ...           0          1
# 147744  Kolkata Knight Riders        field  ...           1          0
# 147745  Kolkata Knight Riders        field  ...           1          0
# 147746  Kolkata Knight Riders        field  ...           4          0
# 147747  Kolkata Knight Riders        field  ...           1          0
#
#        total_run  non_boundary isWicketDelivery player_out kind  \
# 0              0             0                0        NaN  NaN
# 1              1             0                0        NaN  NaN
# 2              1             0                0        NaN  NaN
# 3              0             0                0        NaN  NaN
# 4              0             0                0        NaN  NaN
# ...          ...           ...              ...        ...  ...
# 147743         1             0                0        NaN  NaN
# 147744         1             0                0        NaN  NaN
# 147745         1             0                0        NaN  NaN
# 147746         4             0                0        NaN  NaN
# 147747         1             0                0        NaN  NaN
#
#        fielders_involved       BattingTeam EconomyRate
# 0                    NaN  Rajasthan Royals    7.793651
# 1                    NaN  Rajasthan Royals    7.793651
# 2                    NaN  Rajasthan Royals    7.793651
# 3                    NaN  Rajasthan Royals    7.793651
# 4                    NaN  Rajasthan Royals    7.793651
# ...                  ...               ...         ...
# 147743               NaN  Rajasthan Royals    8.777778
# 147744               NaN  Rajasthan Royals    8.777778
# 147745               NaN  Rajasthan Royals    8.777778
# 147746               NaN  Rajasthan Royals    8.777778
# 147747               NaN  Rajasthan Royals    8.777778
#
# [2118 rows x 37 columns]

# %%
grouped_data = ipl.merge(bbb_deliveries, on='ID').groupby(['Season', 'bowler'])['isWicketDelivery'].sum()

max_wickets_per_season = grouped_data.reset_index().groupby('Season').apply(lambda x: x.loc[x['isWicketDelivery'].idxmax()])

print(max_wickets_per_season[['bowler', 'isWicketDelivery']])
# Out:
#                 bowler  isWicketDelivery
# Season
# 2007/08  Sohail Tanvir                24
# 2009          RP Singh                26
# 2009/10        PP Ojha                22
# 2011        SL Malinga                30
# 2012          M Morkel                30
# 2013          DJ Bravo                34
# 2014         MM Sharma                26
# 2015          DJ Bravo                28
# 2016           B Kumar                24
# 2017           B Kumar                28
# 2018            AJ Tye                28
# 2019          K Rabada                29
# 2020/21       K Rabada                32
# 2021          HV Patel                35
# 2022         YS Chahal                29

# %% [markdown]
# ###`Q-7:` Best bowler in death overs.
# *Note: Have taken most no of wickets in case of tie with least economy*
#
# Death Overs - [16-20]

# %%
# code here
# Out:
#              ID         City        Date   Season MatchNumber  \
# 220186   336006    Bangalore  2008-05-05  2007/08          25
# 217482   336020        Delhi  2008-05-15  2007/08          37
# 217123   336021       Mumbai  2008-05-16  2007/08          38
# 215019   336032        Delhi  2008-05-24  2007/08          50
# 224519   335988    Hyderabad  2008-04-22  2007/08           7
# ...         ...          ...         ...      ...         ...
# 4509    1304102  Navi Mumbai  2022-05-09     2022          56
# 3242    1304107         Pune  2022-05-14     2022          61
# 14989   1304059       Mumbai  2022-04-05     2022          13
# 15941   1304055       Mumbai  2022-04-02     2022           9
# 10869   1304075         Pune  2022-04-17     2022          29
#
#                               Team1                        Team2  \
# 220186  Royal Challengers Bangalore              Kings XI Punjab
# 217482             Delhi Daredevils              Deccan Chargers
# 217123               Mumbai Indians        Kolkata Knight Riders
# 215019             Delhi Daredevils               Mumbai Indians
# 224519              Deccan Chargers             Delhi Daredevils
# ...                             ...                          ...
# 4509          Kolkata Knight Riders               Mumbai Indians
# 3242          Kolkata Knight Riders          Sunrisers Hyderabad
# 14989              Rajasthan Royals  Royal Challengers Bangalore
# 15941              Rajasthan Royals               Mumbai Indians
# 10869           Chennai Super Kings               Gujarat Titans
#
#                                                 Venue  \
# 220186                          M Chinnaswamy Stadium
# 217482                               Feroz Shah Kotla
# 217123                               Wankhede Stadium
# 215019                               Feroz Shah Kotla
# 224519      Rajiv Gandhi International Stadium, Uppal
# ...                                               ...
# 4509               Dr DY Patil Sports Academy, Mumbai
# 3242    Maharashtra Cricket Association Stadium, Pune
# 14989                        Wankhede Stadium, Mumbai
# 15941              Dr DY Patil Sports Academy, Mumbai
# 10869   Maharashtra Cricket Association Stadium, Pune
#
#                          TossWinner TossDecision  ... extra_type batsman_run  \
# 220186              Kings XI Punjab        field  ...        NaN           0
# 217482              Deccan Chargers        field  ...        NaN           0
# 217123               Mumbai Indians        field  ...      wides           0
# 215019             Delhi Daredevils        field  ...        NaN           4
# 224519              Deccan Chargers          bat  ...        NaN           0
# ...                             ...          ...  ...        ...         ...
# 4509                 Mumbai Indians        field  ...        NaN           0
# 3242          Kolkata Knight Riders          bat  ...        NaN           0
# 14989   Royal Challengers Bangalore        field  ...        NaN           6
# 15941                Mumbai Indians        field  ...        NaN           1
# 10869                Gujarat Titans        field  ...        NaN           4
#
#        extras_run  total_run non_boundary isWicketDelivery player_out kind  \
# 220186          0          0            0                0        NaN  NaN
# 217482          0          0            0                0        NaN  NaN
# 217123          1          1            0                0        NaN  NaN
# 215019          0          4            0                0        NaN  NaN
# 224519          0          0            0                0        NaN  NaN
# ...           ...        ...          ...              ...        ...  ...
# 4509            0          0            0                0        NaN  NaN
# 3242            0          0            0                0        NaN  NaN
# 14989           0          6            0                0        NaN  NaN
# 15941           0          1            0                0        NaN  NaN
# 10869           0          4            0                0        NaN  NaN
#
#        fielders_involved                  BattingTeam
# 220186               NaN              Kings XI Punjab
# 217482               NaN              Deccan Chargers
# 217123               NaN        Kolkata Knight Riders
# 215019               NaN             Delhi Daredevils
# 224519               NaN             Delhi Daredevils
# ...                  ...                          ...
# 4509                 NaN               Mumbai Indians
# 3242                 NaN        Kolkata Knight Riders
# 14989                NaN  Royal Challengers Bangalore
# 15941                NaN               Mumbai Indians
# 10869                NaN          Chennai Super Kings
#
# [1673 rows x 36 columns]

# %% [markdown]
# ###`Q-8` Batsman record season wise
#
# Make a function which takes a input `batsman_name` and it returns a dataframe.
# Columns of the data frame are - `['Season','Innings', 'TotalRuns', 'Avg', 'HighestScore','StrikeRate']`.
# * In result make `Season` column as index.
#
# * Avg - total_runs/ no of time got out. - player_out column will help.
# * StrikeRate -(total_runs/ balls faced) * 100- wides are not included in batsman ball faced counts. No balls are included. -> Extra_type column will help
# * Batsman Can score runs on No Balls.
# * Batsman can get out on No Ball or Wides. And even while being on non-striker. Keep these things in mind before masking.

# %%
# code here

# %% [markdown]
# ###`Q-9` Using both dataset, make a dataframe as described below
#
# Data Frame columns-> `['PlayerOfThematch', 'BattingFigure', 'BowlingFigure']`
#
# * BattingFigure->`<runs>/<balls>`
# * BowlingFigure->`<wicket>/<runs-conceded>`
#
# DataFrame should have one record for each match.
#
# Say 'V Kohli' got POM award then in dataset include his batting figure of that match. Say he scored 112runs in 76 balls. And he hasn't bowled so Bowling Figure will be NaN
# ```
# PlayerOfThematch BattingFigure BowlingFigure
# V Kohli          112/76         nan
#
# ```

# %%
# code here

# %% [markdown]
# ## **Questions Based on Iris Dataset**
#
# - **Sepal All:** https://docs.google.com/spreadsheets/d/e/2PACX-1vT58ekmHTwptX7Bs4QOy6YByA1HMvYTACeeIjrKhHE0Pg1K_3egewHMKMh02zN9D5-yHVXfvuaa3s5u/pub?gid=2028782809&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating this sub-dataset.
#     - **Id:** Id of the records.
#     - **SepalLengthCm:** Sepal length of flowers in cm
#     - **SepalWidthCm:** Sepal width of flowers in cm
#
# - **Petal All:** https://docs.google.com/spreadsheets/d/e/2PACX-1vQinLXShrOz4ExNaW1bSQVuvbbhIzJW7G0kkkD2SvqSD6STjLrQQiftgI7BGe10sBZi0CNr2_sJpQAz/pub?gid=1580010789&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating this sub-dataset.
#     - **Id:** Id of the records.
#     - **PetalLengthCm:** Petal length of flowers in cm
#     - **PetalWidthCm:** Petal width of flowers in cm
#
# - **Iris Virginica:** https://docs.google.com/spreadsheets/d/e/2PACX-1vSK39MwduGPHYNgw5yViezoLYCVDKMCWIHzjnt3GZNaxHPFOQLr2q6no_tyqTsOk-VfXleslfGVe9eJ/pub?gid=314231613&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating the sub-dataset.
#     - **Id:** Id of the records.
#     - **Species:** Name of this species.
#
# - **Iris Versicolor:** https://docs.google.com/spreadsheets/d/e/2PACX-1vTcSFgLnabqIrgIc5WlwvnbbvyyJsgZjR-0E0-4TR-5aHgv_0EP6yNWglkkls3AXM2qHCR5VYzWCoTM/pub?gid=715607857&single=true&output=csv
#     - **Unnamed: 0:** Unused column. This column is created when creating the sub-dataset.
#     - **Id:** Id of the records.
#     - **Species:** Name of this species.
#
# - **Iris Setosa:** https://docs.google.com/spreadsheets/d/e/2PACX-1vSjqJpdgy2X_oDUUqQ0sSaFKqnnf8MYU4KgJSYgHaHmq0Wb1weMOsJXh-rICHmkLcaTkOwzMYLeh959/pub?gid=2003684803&single=true&output=csv
#     - **Unnamed 0:** Unused column. This column is created when creating the sub-dataset.
#     - **Id:** Id of the records.
#     - **Species:** Name of this species.

# %%
import pandas as pd
sepal_all = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT58ekmHTwptX7Bs4QOy6YByA1HMvYTACeeIjrKhHE0Pg1K_3egewHMKMh02zN9D5-yHVXfvuaa3s5u/pub?gid=2028782809&single=true&output=csv")
petal_all = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQinLXShrOz4ExNaW1bSQVuvbbhIzJW7G0kkkD2SvqSD6STjLrQQiftgI7BGe10sBZi0CNr2_sJpQAz/pub?gid=1580010789&single=true&output=csv")

virginica = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSK39MwduGPHYNgw5yViezoLYCVDKMCWIHzjnt3GZNaxHPFOQLr2q6no_tyqTsOk-VfXleslfGVe9eJ/pub?gid=314231613&single=true&output=csv")
versicolor = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTcSFgLnabqIrgIc5WlwvnbbvyyJsgZjR-0E0-4TR-5aHgv_0EP6yNWglkkls3AXM2qHCR5VYzWCoTM/pub?gid=715607857&single=true&output=csv")
setosa = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSjqJpdgy2X_oDUUqQ0sSaFKqnnf8MYU4KgJSYgHaHmq0Wb1weMOsJXh-rICHmkLcaTkOwzMYLeh959/pub?gid=2003684803&single=true&output=csv")

# %% [markdown]
# ### `Q-9:` Plot a bar chart of the average Sepal Length  of Virginica and average Petal length of Setosa flower.

# %%
# code here

# %% [markdown]
# ### `Q-10:` Create the complete dataset by uisng the below datasets:
# - virginica
# - versicolor
# - setosa
# - sepal all
# - petal all
#
# This dataset should have these below column names in order:
# 1. Id
# 2. Species
# 3. SepalLengthCm
# 4. SepalWidthCm
# 5. PetalLengthCm
# 6. PetalWidthCm
#
# Also, the dataset should be shuffled means the `Id` column should not be in increasing or decreasing order. So, make a dataset which has the shuffled Id column. You can use `DataFrame.sample()` method to shuffle.

# %%
# code here

# %% [markdown]
# ### `Q-11:` Find out the maximum and minimum sepal width and petal width of Setosa and Versicolor. To do this:
# - First create a dataset with merging the required datasets
# - After that, use `groupby` to create groups based on the "Species" column.
# - Then find out which are asked in this question.
#
#
# The output should be like this:
# ```bash
# Minimum Sepal width of Setosa is 2.3
# Maximum Sepal width of Setosa is 4.4
#
# **************************************************
#
# Minimum Sepal width of Versicolor is 2.0
# Maximum Sepal width of Versicolor is 3.4
#
# **************************************************
# ```

# %%
# code here
